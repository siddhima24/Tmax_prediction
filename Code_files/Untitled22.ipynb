# %%
import os
import pickle
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

districts = ["beed"]#,"Chhatrapati Sambhajinagar","Dhule","Jalgaon","Jalna","Wardha","Yavatmal"]


def train_for_district(district):

    safe_name = district.lower().replace(" ", "_")

    df = pd.read_csv(f"{district}_master_2014_2025.csv")
    df['date'] = pd.to_datetime(df['date'])
    df = df.sort_values('date').reset_index(drop=True)
    df['month'] = df['date'].dt.month
    train_df = df.copy()
    print("Train period:", train_df['date'].min(), "to", train_df['date'].max())

    feature_cols = [
        'msl', 'wind_speed', 'solar_radiation',
        'relative_humidity', 'rainfall', 'month'
    ]
    target_col = 'tmax'

    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    train_df[feature_cols] = scaler_X.fit_transform(train_df[feature_cols])
    train_df[[target_col]] = scaler_y.fit_transform(train_df[[target_col]])

    def create_sequences(data, target, window=4, horizon=15):
        X, y = [], []
        for i in range(len(data) - window - horizon):
            X.append(data[i:i+window])
            y.append(target[i+window:i+window+horizon])
        return np.array(X), np.array(y)

    X_train, y_train = create_sequences(
        train_df[feature_cols].values,
        train_df[target_col].values,
        window=4,
        horizon=15
    )
    print("X_train shape:", X_train.shape)
    print("y_train shape:", y_train.shape)

    model = Sequential()

    model.add(Conv1D(filters=224, kernel_size=1, activation='relu',
                     input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Conv1D(filters=192, kernel_size=1, activation='relu'))
    model.add(Dropout(0.30))

    model.add(LSTM(64, return_sequences=True))
    model.add(LSTM(64, return_sequences=True))
    model.add(LSTM(64))

    model.add(Dropout(0.10))
    model.add(Dense(15))

    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss='mae'
    )

    model.summary()

    history = model.fit(
        X_train, y_train,
        epochs=200,
        batch_size=32,
        validation_split=0.1,
        verbose=1
    )

    os.makedirs("models", exist_ok=True)
    os.makedirs("scalers", exist_ok=True)

    model.save(f"models/{safe_name}_model.keras")

    with open(f"scalers/{safe_name}_scalers.pkl", "wb") as f:
        pickle.dump({
            "scaler_X": scaler_X,
            "scaler_y": scaler_y
        }, f)


for district in districts:
    print(f"\nTraining model for {district.upper()}")
    train_for_district(district)
# Out:
# Training model for BEED
# Train period: 2015-01-01 00:00:00 to 2025-12-31 00:00:00
# X_train shape: (3999, 4, 6)
# y_train shape: (3999, 15)
# c:\Users\sid24\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 4, 224)         │         1,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 4, 192)         │        43,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 4, 192)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 4, 64)          │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 4, 64)          │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 15)             │           975 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 177,583 (693.68 KB)
#  Trainable params: 177,583 (693.68 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.3554 - val_loss: 0.1632
# Epoch 2/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1415 - val_loss: 0.0887
# Epoch 3/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1095 - val_loss: 0.0851
# Epoch 4/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1020 - val_loss: 0.0791
# Epoch 5/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1000 - val_loss: 0.0846
# Epoch 6/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0983 - val_loss: 0.0784
# Epoch 7/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0964 - val_loss: 0.0744
# Epoch 8/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0947 - val_loss: 0.0728
# Epoch 9/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0934 - val_loss: 0.0726
# Epoch 10/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0924 - val_loss: 0.0752
# Epoch 11/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0914 - val_loss: 0.0753
# Epoch 12/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0896 - val_loss: 0.0760
# Epoch 13/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0893 - val_loss: 0.0726
# Epoch 14/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0889 - val_loss: 0.0717
# Epoch 15/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0876 - val_loss: 0.0774
# Epoch 16/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0875 - val_loss: 0.0730
# Epoch 17/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0867 - val_loss: 0.0715
# Epoch 18/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0854 - val_loss: 0.0789
# Epoch 19/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0856 - val_loss: 0.0722
# Epoch 20/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0848 - val_loss: 0.0760
# Epoch 21/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0841 - val_loss: 0.0769
# Epoch 22/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0829 - val_loss: 0.0779
# Epoch 23/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0834 - val_loss: 0.0738
# Epoch 24/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0827 - val_loss: 0.0770
# Epoch 25/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0821 - val_loss: 0.0749
# Epoch 26/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0820 - val_loss: 0.0728
# Epoch 27/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0814 - val_loss: 0.0750
# Epoch 28/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0813 - val_loss: 0.0769
# Epoch 29/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0815 - val_loss: 0.0767
# Epoch 30/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0803 - val_loss: 0.0738
# Epoch 31/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0804 - val_loss: 0.0774
# Epoch 32/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0796 - val_loss: 0.0760
# Epoch 33/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0795 - val_loss: 0.0744
# Epoch 34/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0787 - val_loss: 0.0746
# Epoch 35/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0786 - val_loss: 0.0737
# Epoch 36/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0784 - val_loss: 0.0706
# Epoch 37/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0785 - val_loss: 0.0742
# Epoch 38/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0779 - val_loss: 0.0751
# Epoch 39/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0776 - val_loss: 0.0740
# Epoch 40/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0770 - val_loss: 0.0753
# Epoch 41/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0776 - val_loss: 0.0726
# Epoch 42/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0774 - val_loss: 0.0727
# Epoch 43/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0772 - val_loss: 0.0755
# Epoch 44/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0766 - val_loss: 0.0763
# Epoch 45/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0761 - val_loss: 0.0752
# Epoch 46/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0767 - val_loss: 0.0742
# Epoch 47/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0763 - val_loss: 0.0782
# Epoch 48/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0763 - val_loss: 0.0759
# Epoch 49/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0761 - val_loss: 0.0765
# Epoch 50/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0760 - val_loss: 0.0779
# Epoch 51/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0758 - val_loss: 0.0742
# Epoch 52/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0756 - val_loss: 0.0726
# Epoch 53/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0759 - val_loss: 0.0779
# Epoch 54/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0752 - val_loss: 0.0726
# Epoch 55/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0749 - val_loss: 0.0757
# Epoch 56/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0751 - val_loss: 0.0743
# Epoch 57/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0748 - val_loss: 0.0725
# Epoch 58/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0749 - val_loss: 0.0753
# Epoch 59/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0746 - val_loss: 0.0769
# Epoch 60/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0744 - val_loss: 0.0750
# Epoch 61/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0752 - val_loss: 0.0754
# Epoch 62/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0738 - val_loss: 0.0769
# Epoch 63/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0742 - val_loss: 0.0757
# Epoch 64/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0739 - val_loss: 0.0727
# Epoch 65/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0741 - val_loss: 0.0730
# Epoch 66/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0736 - val_loss: 0.0758
# Epoch 67/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0735 - val_loss: 0.0729
# Epoch 68/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0738 - val_loss: 0.0751
# Epoch 69/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0737 - val_loss: 0.0757
# Epoch 70/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0740 - val_loss: 0.0753
# Epoch 71/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0731 - val_loss: 0.0743
# Epoch 72/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0734 - val_loss: 0.0760
# Epoch 73/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0733 - val_loss: 0.0760
# Epoch 74/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0731 - val_loss: 0.0767
# Epoch 75/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0732 - val_loss: 0.0745
# Epoch 76/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0729 - val_loss: 0.0754
# Epoch 77/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0724 - val_loss: 0.0772
# Epoch 78/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0731 - val_loss: 0.0777
# Epoch 79/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0725 - val_loss: 0.0819
# Epoch 80/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0723 - val_loss: 0.0735
# Epoch 81/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0724 - val_loss: 0.0771
# Epoch 82/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0720 - val_loss: 0.0764
# Epoch 83/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0724 - val_loss: 0.0795
# Epoch 84/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0723 - val_loss: 0.0782
# Epoch 85/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0722 - val_loss: 0.0780
# Epoch 86/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0714 - val_loss: 0.0760
# Epoch 87/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0719 - val_loss: 0.0773
# Epoch 88/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0723 - val_loss: 0.0792
# Epoch 89/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0716 - val_loss: 0.0748
# Epoch 90/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0721 - val_loss: 0.0809
# Epoch 91/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0718 - val_loss: 0.0734
# Epoch 92/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0717 - val_loss: 0.0757
# Epoch 93/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0711 - val_loss: 0.0758
# Epoch 94/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0717 - val_loss: 0.0786
# Epoch 95/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0717 - val_loss: 0.0764
# Epoch 96/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0712 - val_loss: 0.0734
# Epoch 97/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0713 - val_loss: 0.0780
# Epoch 98/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0714 - val_loss: 0.0746
# Epoch 99/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0708 - val_loss: 0.0758
# Epoch 100/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0710 - val_loss: 0.0763
# Epoch 101/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0707 - val_loss: 0.0742
# Epoch 102/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0706 - val_loss: 0.0779
# Epoch 103/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0710 - val_loss: 0.0787
# Epoch 104/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0705 - val_loss: 0.0751
# Epoch 105/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0708 - val_loss: 0.0784
# Epoch 106/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0709 - val_loss: 0.0742
# Epoch 107/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0705 - val_loss: 0.0740
# Epoch 108/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0707 - val_loss: 0.0771
# Epoch 109/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0703 - val_loss: 0.0778
# Epoch 110/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0706 - val_loss: 0.0775
# Epoch 111/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0699 - val_loss: 0.0769
# Epoch 112/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0705 - val_loss: 0.0765
# Epoch 113/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0699 - val_loss: 0.0727
# Epoch 114/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0701 - val_loss: 0.0745
# Epoch 115/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0705 - val_loss: 0.0766
# Epoch 116/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0697 - val_loss: 0.0801
# Epoch 117/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0698 - val_loss: 0.0770
# Epoch 118/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0702 - val_loss: 0.0756
# Epoch 119/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0700 - val_loss: 0.0780
# Epoch 120/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0701 - val_loss: 0.0743
# Epoch 121/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0696 - val_loss: 0.0765
# Epoch 122/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0696 - val_loss: 0.0729
# Epoch 123/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0695 - val_loss: 0.0717
# Epoch 124/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0697 - val_loss: 0.0766
# Epoch 125/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0698 - val_loss: 0.0772
# Epoch 126/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0698 - val_loss: 0.0759
# Epoch 127/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0694 - val_loss: 0.0804
# Epoch 128/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0693 - val_loss: 0.0773
# Epoch 129/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0697 - val_loss: 0.0771
# Epoch 130/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0698 - val_loss: 0.0776
# Epoch 131/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0692 - val_loss: 0.0768
# Epoch 132/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0692 - val_loss: 0.0781
# Epoch 133/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0694 - val_loss: 0.0747
# Epoch 134/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0692 - val_loss: 0.0795
# Epoch 135/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0689 - val_loss: 0.0749
# Epoch 136/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0692 - val_loss: 0.0745
# Epoch 137/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0689 - val_loss: 0.0765
# Epoch 138/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0691 - val_loss: 0.0758
# Epoch 139/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0689 - val_loss: 0.0760
# Epoch 140/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0690 - val_loss: 0.0789
# Epoch 141/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0690 - val_loss: 0.0767
# Epoch 142/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0686 - val_loss: 0.0733
# Epoch 143/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0690 - val_loss: 0.0780
# Epoch 144/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0689 - val_loss: 0.0766
# Epoch 145/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0686 - val_loss: 0.0757
# Epoch 146/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0691 - val_loss: 0.0740
# Epoch 147/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0687 - val_loss: 0.0747
# Epoch 148/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0685 - val_loss: 0.0728
# Epoch 149/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0690 - val_loss: 0.0764
# Epoch 150/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0690 - val_loss: 0.0754
# Epoch 151/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0682 - val_loss: 0.0755
# Epoch 152/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0684 - val_loss: 0.0776
# Epoch 153/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0681 - val_loss: 0.0779
# Epoch 154/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0685 - val_loss: 0.0768
# Epoch 155/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0683 - val_loss: 0.0763
# Epoch 156/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0683 - val_loss: 0.0801
# Epoch 157/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0683 - val_loss: 0.0736
# Epoch 158/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0683 - val_loss: 0.0724
# Epoch 159/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0681 - val_loss: 0.0764
# Epoch 160/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0680 - val_loss: 0.0770
# Epoch 161/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0678 - val_loss: 0.0768
# Epoch 162/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0679 - val_loss: 0.0760
# Epoch 163/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0684 - val_loss: 0.0776
# Epoch 164/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0681 - val_loss: 0.0761
# Epoch 165/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0678 - val_loss: 0.0769
# Epoch 166/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0681 - val_loss: 0.0749
# Epoch 167/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0684 - val_loss: 0.0778
# Epoch 168/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0677 - val_loss: 0.0739
# Epoch 169/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0674 - val_loss: 0.0790
# Epoch 170/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0679 - val_loss: 0.0719
# Epoch 171/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0675 - val_loss: 0.0772
# Epoch 172/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0673 - val_loss: 0.0776
# Epoch 173/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0673 - val_loss: 0.0740
# Epoch 174/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0675 - val_loss: 0.0779
# Epoch 175/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0675 - val_loss: 0.0722
# Epoch 176/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0674 - val_loss: 0.0749
# Epoch 177/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0670 - val_loss: 0.0783
# Epoch 178/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0675 - val_loss: 0.0748
# Epoch 179/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0671 - val_loss: 0.0723
# Epoch 180/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0669 - val_loss: 0.0757
# Epoch 181/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0674 - val_loss: 0.0736
# Epoch 182/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0675 - val_loss: 0.0750
# Epoch 183/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0674 - val_loss: 0.0777
# Epoch 184/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0671 - val_loss: 0.0851
# Epoch 185/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0675 - val_loss: 0.0739
# Epoch 186/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0673 - val_loss: 0.0752
# Epoch 187/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0669 - val_loss: 0.0789
# Epoch 188/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0673 - val_loss: 0.0752
# Epoch 189/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0674 - val_loss: 0.0758
# Epoch 190/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0673 - val_loss: 0.0770
# Epoch 191/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0678 - val_loss: 0.0780
# Epoch 192/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0668 - val_loss: 0.0778
# Epoch 193/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0670 - val_loss: 0.0785
# Epoch 194/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0671 - val_loss: 0.0787
# Epoch 195/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0668 - val_loss: 0.0764
# Epoch 196/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0676 - val_loss: 0.0730
# Epoch 197/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0669 - val_loss: 0.0771
# Epoch 198/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0671 - val_loss: 0.0767
# Epoch 199/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0669 - val_loss: 0.0742
# Epoch 200/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0666 - val_loss: 0.0740

# %%
import requests
import pickle
import numpy as np
import pandas as pd
from datetime import datetime, timedelta, date
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import load_model

# ============================================================
# DISTRICT COORDINATES
# ============================================================
DISTRICT_COORDS = {
    "beed":                      {"lat": 18.9901, "lon": 75.7531},
    "Chhatrapati Sambhajinagar": {"lat": 19.8762, "lon": 75.3433},
    "Dhule":                     {"lat": 20.9042, "lon": 74.7749},
    "Jalgaon":                   {"lat": 21.0077, "lon": 75.5626},
    "Jalna":                     {"lat": 19.8410, "lon": 75.8864},
    "Wardha":                    {"lat": 20.7453, "lon": 78.6022},
    "Yavatmal":                  {"lat": 20.3899, "lon": 78.1307},
}

# ============================================================
# USER INPUT
# ============================================================
district_input = input("Enter district: ").strip()
date_input     = input("Enter prediction date (YYYY-MM-DD): ").strip()

# safe_name for model/scaler filenames
district_key = district_input.lower().replace(" ", "_")

# match exact key from DISTRICT_COORDS
district_cap = None
for key in DISTRICT_COORDS:
    if key.lower() == district_input.lower():
        district_cap = key
        break

if district_cap is None:
    raise ValueError(
        f"District '{district_input}' not found.\n"
        f"Available districts: {list(DISTRICT_COORDS.keys())}"
    )


# ============================================================
# FETCHER — meteorological inputs  (unit-corrected to match ERA5)
#
# ERA5 training data units:
#   msl              → Pa        (Open-Meteo gives hPa  → × 100)
#   wind_speed       → m/s       (Open-Meteo gives km/h → ÷ 3.6)
#   solar_radiation  → J/m²      (Open-Meteo gives W/m² hourly sum → × 3600)
#   relative_humidity→ %         (Open-Meteo gives % at 2m → same)
#   rainfall         → mm        (same)
# ============================================================
def fetch_paper_style_inputs(date_str, district):
    lat = DISTRICT_COORDS[district]["lat"]
    lon = DISTRICT_COORDS[district]["lon"]

    target_date = datetime.strptime(date_str, "%Y-%m-%d").date()
    start_date  = target_date - timedelta(days=4)
    end_date    = target_date
    today_real  = date.today()

    if end_date < today_real - timedelta(days=2):
        base_url = "https://archive-api.open-meteo.com/v1/archive"
    else:
        base_url = "https://api.open-meteo.com/v1/forecast"

    url = (
        f"{base_url}?"
        f"latitude={lat}&longitude={lon}"
        f"&hourly=relativehumidity_2m,"
        f"pressure_msl,windspeed_10m,"
        f"shortwave_radiation,precipitation"
        f"&start_date={start_date}&end_date={end_date}"
        f"&timezone=Asia/Kolkata"
    )

    for _ in range(3):
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            break
        except:
            print("Retrying API call...")

    data   = response.json()
    hourly = pd.DataFrame(data["hourly"])
    hourly["time"] = pd.to_datetime(hourly["time"])
    hourly["date"] = hourly["time"].dt.date

    daily = hourly.groupby("date").agg({
        "relativehumidity_2m": "mean",   # %  → same
        "pressure_msl":        "mean",   # hPa → will convert below
        "windspeed_10m":       "mean",   # km/h → will convert below
        "shortwave_radiation": "sum",    # W/m² sum → will convert below
        "precipitation":       "sum",    # mm → same
    }).reset_index()

    # ---- Unit conversions to match ERA5 training data ----
    daily["pressure_msl"]    = daily["pressure_msl"]    * 100      # hPa  → Pa
    daily["windspeed_10m"]   = daily["windspeed_10m"]   / 3.6      # km/h → m/s
    daily["shortwave_radiation"] = daily["shortwave_radiation"] * 3600  # W/m² → J/m²

    daily["month_index"] = pd.to_datetime(daily["date"]).dt.month

    daily = daily.rename(columns={
        "pressure_msl":        "msl",
        "windspeed_10m":       "wind_speed",
        "shortwave_radiation": "solar_radiation",
        "relativehumidity_2m": "relative_humidity",
        "precipitation":       "rainfall",
        "month_index":         "month",
    })

    daily = daily[["date","msl","wind_speed","solar_radiation",
                   "relative_humidity","rainfall","month"]]

    daily = daily.fillna(method="ffill").fillna(method="bfill")
    daily["date"] = pd.to_datetime(daily["date"])
    daily = daily.set_index("date")
    return daily


# ============================================================
# FETCHER — actual Tmax  (°C, same as IMD training data)
# ============================================================
def fetch_tmax(date_str, district):
    lat = DISTRICT_COORDS[district]["lat"]
    lon = DISTRICT_COORDS[district]["lon"]

    target_date = datetime.strptime(date_str, "%Y-%m-%d").date()
    start_date  = target_date - timedelta(days=4)
    end_date    = target_date
    today_real  = date.today()

    if end_date < today_real - timedelta(days=2):
        base_url = "https://archive-api.open-meteo.com/v1/archive"
    else:
        base_url = "https://api.open-meteo.com/v1/forecast"

    url = (
        f"{base_url}?"
        f"latitude={lat}&longitude={lon}"
        f"&hourly=temperature_2m"
        f"&start_date={start_date}&end_date={end_date}"
        f"&timezone=Asia/Kolkata"
    )

    response = requests.get(url)
    response.raise_for_status()
    data = response.json()

    hourly = pd.DataFrame(data["hourly"])
    hourly["time"] = pd.to_datetime(hourly["time"])
    hourly["date"] = hourly["time"].dt.date

    daily = hourly.groupby("date").agg({"temperature_2m": "max"}).reset_index()
    daily["date"] = pd.to_datetime(daily["date"])
    daily = daily.set_index("date")
    daily = daily.ffill().bfill()

    try:
        return float(daily["temperature_2m"].iloc[-1])
    except:
        return None


# ============================================================
# LOAD MODEL + SCALERS
# ============================================================
model = load_model(f"models/{district_key}_model.keras")

with open(f"scalers/{district_key}_scalers.pkl", "rb") as f:
    scalers = pickle.load(f)

scaler_X = scalers["scaler_X"]
scaler_y = scalers["scaler_y"]

print(f"\nModel and scalers loaded for: {district_cap}\n")


# ============================================================
# FETCH INPUTS & RUN PREDICTION
# ============================================================
df = fetch_paper_style_inputs(date_input, district_cap)
df = df.sort_values("date")

features    = df[["msl","wind_speed","solar_radiation",
                   "relative_humidity","rainfall","month"]]
last_4_days = features.head(4)
scaled      = scaler_X.transform(last_4_days)
X_input     = np.expand_dims(scaled, axis=0)   # shape (1, 4, 6)

pred_scaled = model.predict(X_input)
pred_tmax   = scaler_y.inverse_transform(pred_scaled)[0]


# ============================================================
# PREDICTION RESULTS DATAFRAME
# ============================================================
base_date    = pd.to_datetime(date_input)
future_dates = [base_date + pd.Timedelta(days=i+1) for i in range(15)]

results_df = pd.DataFrame({
    "Day":            [f"Day {i+1:02d}" for i in range(15)],
    "Date":           [d.strftime("%Y-%m-%d") for d in future_dates],
    "Predicted_Tmax": [round(float(t), 2) for t in pred_tmax],
})

print("\n15-Day Tmax Forecast")
print("=" * 40)
print(results_df.to_string(index=False))
print("=" * 40)


# ============================================================
# RMSE CALCULATION
# Fetches actual Tmax for each of the 15 forecast days
# and computes RMSE per horizon
# ============================================================
print("\nFetching actual Tmax values for RMSE...")

pred_horizon   = [[] for _ in range(15)]
actual_horizon = [[] for _ in range(15)]

for i in range(15):
    target_date = base_date + pd.Timedelta(days=i+1)
    target_str  = target_date.strftime("%Y-%m-%d")

    try:
        actual = fetch_tmax(target_str, district_cap)
        if actual is None:
            print(f"  Day {i+1:02d}: actual Tmax not available")
            continue
        actual = float(actual)
    except Exception as e:
        print(f"  Day {i+1:02d}: fetch failed — {e}")
        continue

    pred_horizon[i].append(float(np.squeeze(pred_tmax[i])))
    actual_horizon[i].append(actual)

# Build RMSE dataframe
rmse_rows = []
for i in range(15):
    pred_val   = round(float(pred_tmax[i]), 2)
    if len(actual_horizon[i]) == 0:
        rmse_rows.append({
            "Day":            f"Day {i+1:02d}",
            "Date":           future_dates[i].strftime("%Y-%m-%d"),
            "Predicted_Tmax": pred_val,
            "Actual_Tmax":    "N/A",
            "RMSE":           "N/A",
        })
    else:
        rmse = round(np.sqrt(mean_squared_error(actual_horizon[i], pred_horizon[i])), 2)
        rmse_rows.append({
            "Day":            f"Day {i+1:02d}",
            "Date":           future_dates[i].strftime("%Y-%m-%d"),
            "Predicted_Tmax": pred_val,
            "Actual_Tmax":    round(actual_horizon[i][0], 2),
            "RMSE":           rmse,
        })

rmse_df = pd.DataFrame(rmse_rows)

print("\n===================================")
print(" HORIZON-WISE RMSE")
print("===================================\n")
print(rmse_df.to_string(index=False))
print("=" * 55)
# Out:
# Model and scalers loaded for: beed
# C:\Users\sid24\AppData\Local\Temp\ipykernel_27140\3592696040.py:119: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily = daily.fillna(method="ffill").fillna(method="bfill")
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
#
# 15-Day Tmax Forecast
# ========================================
#    Day       Date  Predicted_Tmax
# Day 01 2026-01-02           30.81
# Day 02 2026-01-03           30.60
# Day 03 2026-01-04           30.44
# Day 04 2026-01-05           30.32
# Day 05 2026-01-06           30.25
# Day 06 2026-01-07           30.17
# Day 07 2026-01-08           30.07
# Day 08 2026-01-09           29.97
# Day 09 2026-01-10           29.91
# Day 10 2026-01-11           29.87
# Day 11 2026-01-12           29.84
# Day 12 2026-01-13           29.87
# Day 13 2026-01-14           29.84
# Day 14 2026-01-15           29.83
# Day 15 2026-01-16           29.88
# ========================================
#
# Fetching actual Tmax values for RMSE...
#
# ===================================
#  HORIZON-WISE RMSE
# ===================================
#
#    Day       Date  Predicted_Tmax  Actual_Tmax  RMSE
# Day 01 2026-01-02           30.81         29.3  1.51
# Day 02 2026-01-03           30.60         28.5  2.10
# Day 03 2026-01-04           30.44         28.5  1.94
# Day 04 2026-01-05           30.32         27.8  2.52
# Day 05 2026-01-06           30.25         27.3  2.95
# Day 06 2026-01-07           30.17         27.9  2.27
# Day 07 2026-01-08           30.07         27.5  2.57
# Day 08 2026-01-09           29.97         26.8  3.17
# Day 09 2026-01-10           29.91         27.0  2.91
# Day 10 2026-01-11           29.87         27.0  2.87
# Day 11 2026-01-12           29.84         28.6  1.24
# Day 12 2026-01-13           29.87         29.8  0.07
# Day 13 2026-01-14           29.84         29.5  0.34
# Day 14 2026-01-15           29.83         29.1  0.73
# Day 15 2026-01-16           29.88         29.5  0.38
# =======================================================
